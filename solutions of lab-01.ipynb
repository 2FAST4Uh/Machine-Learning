# %% [markdown]
# <a href="https://colab.research.google.com/github/2FAST4Uh/Machine-Learning/blob/main/solutions%20of%20lab-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('insurance.csv')

# %%
df #give the complete file
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape #for the size of the file
# Out:
# (1338, 7)

# %%
df.head() #print first 5 records
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.head(10) # print the the first 10 records or change the value give the records accoringly
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail() #print the last 5 records
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.tail(9) # print the the last 9 records or change the value give the records accoringly
# Out:
#       age     sex    bmi  children smoker     region      charges
# 1329   52    male  38.60         2     no  southwest  10325.20600
# 1330   57  female  25.74         2     no  southeast  12629.16560
# 1331   23  female  33.40         0     no  southwest  10795.93733
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1333   50    male  30.97         3     no  northwest  10600.54830
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030

# %%
df.describe() # give the numeric value records
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull() #false represent records not contain null value
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
import pandas as pd

# Load CSV file
df = pd.read_csv("insurance.csv")   # change filename if needed

# Calculate correlation matrix (numeric columns only)
corr = df.corr(numeric_only=True)

# Choose target column
target = "charges"   # change if your target column name is different

print("Correlation values with", target)
print(corr[target])

# Check correlation type
positive = corr[target][corr[target] > 0].count()
negative = corr[target][corr[target] < 0].count()

print("\nSummary:")
if positive > negative:
    print("Dataset shows more POSITIVE correlation")
elif negative > positive:
    print("Dataset shows more NEGATIVE correlation")
else:
    print("Dataset has balanced or NO clear correlation")
# Out:
# Correlation values with charges
# age         0.299008
# bmi         0.198341
# children    0.067998
# charges     1.000000
# Name: charges, dtype: float64
#
# Summary:
# Dataset shows more POSITIVE correlation

# %%
import pandas as pd

# Load CSV file
df = pd.read_csv("insurance.csv")   # change filename if needed

# Calculate correlation matrix (numeric columns only)
corr = df.corr(numeric_only=True)

# Choose target column
target = "age"   # change if your target column name is different

print("Correlation values with", target)
print(corr[target])

# Check correlation type
positive = corr[target][corr[target] > 0].count()
negative = corr[target][corr[target] < 0].count()

print("\nSummary:")
if positive > negative:
    print("Dataset shows more POSITIVE correlation")
elif negative > positive:
    print("Dataset shows more NEGATIVE correlation")
else:
    print("Dataset has balanced or NO clear correlation")
# Out:
# Correlation values with age
# age         1.000000
# bmi         0.109272
# children    0.042469
# charges     0.299008
# Name: age, dtype: float64
#
# Summary:
# Dataset shows more POSITIVE correlation

# %%
import pandas as pd

# Load CSV file
df = pd.read_csv("insurance.csv")   # change filename if needed

# Calculate correlation matrix (numeric columns only)
corr = df.corr(numeric_only=True)

# Choose target column
target = "bmi"   # change if your target column name is different

print("Correlation values with", target)
print(corr[target])

# Check correlation type
positive = corr[target][corr[target] > 0].count()
negative = corr[target][corr[target] < 0].count()

print("\nSummary:")
if positive > negative:
    print("Dataset shows more POSITIVE correlation")
elif negative > positive:
    print("Dataset shows more NEGATIVE correlation")
else:
    print("Dataset has balanced or NO clear correlation")
# Out:
# Correlation values with bmi
# age         0.109272
# bmi         1.000000
# children    0.012759
# charges     0.198341
# Name: bmi, dtype: float64
#
# Summary:
# Dataset shows more POSITIVE correlation

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
data = pd.read_csv('insurance.csv')

# Extract columns
labels = data['bmi']
sizes = data['charges']

# Create pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Title
plt.title('Pie Chart from CSV Data')

# Show chart
plt.show()
